# %%
# 아 너무 느려

# 구글 시트하고 locker studio는 단순하게 데이터를 정렬하기 위한 목적이지 분석하고자 하는 목표가 절대 아니야

# 아 너무 느려

# %%
## 데이터 불러오기 (Load하기)

# %%
import pandas as pd

_gs_busevent_preprocessed = pd.read_csv("_gs_busevent_preprocessed.csv")
_gs_busevent_preprocessed
# Out:
#        route_name  bstop_arrive_time  bstop_leave_time  stop_time  \
# 0             818     20200104000053    20200104000140         49
# 1             818     20200104000214    20200104000240         27
# 2             818     20200104000501    20200104000525         25
# 3             818     20200104000554    20200104000620         27
# 4             818     20200104000648    20200104000658         11
# ...           ...                ...               ...        ...
# 202930        818     20200103235511    20200103235517          6
# 202931        818     20200103235621    20200103235650         30
# 202932        818     20200103235700    20200103235709          9
# 202933        818     20200103235836    20200103235853         18
# 202934        818     20200103235905    20200103235944         41
#
#              node_name  node_x_pos  node_y_pos  bstop_arrive_year  \
# 0               하양초등학교   128.81746    35.91229               2020
# ...

# %%
## 데이터 필터링

# %%
_gs_busevent_preprocessed818 = _gs_busevent_preprocessed.loc[_gs_busevent_preprocessed['route_name'] == '818']
_gs_busevent_preprocessed818
# Out:
#        route_name  bstop_arrive_time  bstop_leave_time  stop_time  \
# 0             818     20200104000053    20200104000140         49
# 1             818     20200104000214    20200104000240         27
# 2             818     20200104000501    20200104000525         25
# 3             818     20200104000554    20200104000620         27
# 4             818     20200104000648    20200104000658         11
# ...           ...                ...               ...        ...
# 202930        818     20200103235511    20200103235517          6
# 202931        818     20200103235621    20200103235650         30
# 202932        818     20200103235700    20200103235709          9
# 202933        818     20200103235836    20200103235853         18
# 202934        818     20200103235905    20200103235944         41
#
#              node_name  node_x_pos  node_y_pos  bstop_arrive_year  \
# 0               하양초등학교   128.81746    35.91229               2020
# ...

# %%
### 데이터 내림차순 정렬

# %%
_gs_busevent_preprocessed818 = _gs_busevent_preprocessed818.sort_values(by='bstop_arrive_time' ,ascending=False)
_gs_busevent_preprocessed818
# Out:
#       route_name  bstop_arrive_time  bstop_leave_time  stop_time   node_name  \
# 33487        818     20200107000935    20200107000942          7    대구대종점 건너
# 33486        818     20200107000921    20200107000930          9    대구대정문 건너
# 33485        818     20200107000908    20200107000915          8  대구대(정문2건너)
# 33484        818     20200107000824    20200107000847         24    대구대서문 건너
# 33483        818     20200107000752    20200107000758          6    내리리입구 건너
# ...          ...                ...               ...        ...         ...
# 20203        818     20200101060831    20200101060839          8     하양성당 건너
# 20200        818     20200101060800    20200101060812         12       구.우시장
# 20192        818     20200101060648    20200101060700         13      하양초등학교
# 20189        818     20200101060545    20200101060631         47         하양역
# 20186        818     20200101060525    20200101060532          7   하양시외버스터미널
#
# ...

# %%
# 차트(그래프) 그리기

# %%
for node_x_pos, node_y_posin  in zip(_gs_busevent_preprocessed818['node_x_pos'], _gs_busevent_preprocessed818['node_y_pos']):
    print(node_x_pos, node_y_posin)
# Out:
# 128.85063 35.89704
# 128.84856 35.89706
# 128.84672 35.89723
# 128.84343 35.89857
# 128.83787 35.9003
# 128.83164 35.9019
# 128.82528 35.90098
# 128.82432 35.90352
# 128.82391 35.90676
# 128.82327 35.9108
# 128.82104 35.91404
# 128.81747 35.91228
# 128.81528 35.91044
# 128.81389 35.90926
# 128.81216 35.90768
# 128.80327 35.90039
# 128.80119 35.8999
# 128.78963 35.89663
# 128.78286 35.8926
# 128.77896 35.88866
# 128.77307 35.88317
# 128.76525 35.87966
# 128.76233 35.87836
# 128.7565 35.87569
# 128.7468 35.87194
# 128.74201 35.8725
# 128.7343 35.87138
# 128.73112 35.87173
# 128.72794 35.87179
# 128.72177 35.87188
# 128.71711 35.87199
# 128.71176 35.87205
# 128.70896 35.87226
# 128.70365 35.87276
# 128.69858 35.87337
# 128.69426 35.87374
# 128.68957 35.87414
# 128.68253 35.87597
# 128.67995 35.87667
# 128.67585 35.87799
# 128.67205 35.87911
# 128.66882 35.88003
# 128.66525 35.88148
# 128.66165 35.88314
# 128.65899 35.88357
# 128.65555 35.88527
# 128.81721 35.88965
# 128.81857 35.89135
# ...
